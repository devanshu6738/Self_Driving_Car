# %% [markdown]
# <a href="https://colab.research.google.com/github/devanshu6738/Self_Driving_Car/blob/main/Lane_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="1bzgWqssLnD7W4MK5P0W")
project = rf.workspace("mit-wpu-3jmcg").project("lane-detection-vxwns")
version = project.version(4)
dataset = version.download("yolov8-obb")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.3/260.3 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 47.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 47.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Lane-Detection-4 in yolov8-obb:: 100%|██████████| 7002/7002 [00:04<00:00, 1592.87it/s]

# %%
# !pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 654.8 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 2.7 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

model = YOLO("yolo11n-seg.pt")  # If your dataset is segmentation

model.train(
    data=dataset.location + "/data.yaml",
    epochs=20,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.4.89 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/segment/train-2/weights/best.pt")

model.train(
    data="/content/Lane-Detection-4/data.yaml",
    epochs=30
)
# Out:
# Ultralytics 8.4.89 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/segment/train-3/weights/best.pt")

# %%
results = model.predict(
    source="/content/test2.mp4",
    save=True,
    imgsz=640,
    conf=0.25,
    device=0
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1295) /content/test2.mp4: 384x640 1 Left Lane, 2 Right Lanes, 61.1ms
# video 1/1 (frame 2/1295) /content/test2.mp4: 384x640 1 Left Lane, 2 Right Lanes, 10.5ms
# video 1/1 (frame 3/1295) /content/test2.mp4: 384x640 1 Middle Lane, 2 Right Lanes, 10.4ms
# video 1/1 (frame 4/1295) /content/test2.mp4: 384x640 1 Middle Lane, 2 Right Lanes, 11.5ms
# ...
